# %% [markdown]
# --------------- TITANIC SURVIVAL DATASET ANALYSIS ---------------

# %% [markdown]
# * Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * Load Dataset

# %%
df = pd.read_csv('Titanic_Survival.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 0            1         1       1     John 1    male  20.3      0      1
# 1            2         0       3     John 2    male  52.3      1      3
# 2            3         1       1     John 3  female  61.3      3      0
# 3            4         0       3  William 4    male  50.7      1      2
# 4            5         1       1   Olivia 5    male  36.8      1      1
#
#       Ticket    Fare Cabin Embarked
# 0  TKT000001   70.50   A10        S
# 1  TKT000002   33.33   NaN        C
# 2  TKT000003  125.99   NaN        C
# 3  TKT000004    7.43   NaN        S
# 4  TKT000005  121.05   A10        S

# %% [markdown]
# * Dataset Information

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 0            1         1       1     John 1    male  20.3      0      1
# 1            2         0       3     John 2    male  52.3      1      3
# 2            3         1       1     John 3  female  61.3      3      0
# 3            4         0       3  William 4    male  50.7      1      2
# 4            5         1       1   Olivia 5    male  36.8      1      1
#
#       Ticket    Fare Cabin Embarked
# 0  TKT000001   70.50   A10        S
# 1  TKT000002   33.33   NaN        C
# 2  TKT000003  125.99   NaN        C
# 3  TKT000004    7.43   NaN        S
# 4  TKT000005  121.05   A10        S

# %%
df.tail()
# Out:
#       PassengerId  Survived  Pclass         Name     Sex   Age  SibSp  Parch  \
# 4995         4996         0       3    Liam 4996    male  76.2      1      0
# 4996         4997         1       1     Mia 4997    male   3.4      1      1
# 4997         4998         1       1   Alice 4998    male  52.3      0      1
# 4998         4999         1       3    Emma 4999  female  58.8      4      3
# 4999         5000         0       2  Sophia 5000    male  45.3      4      0
#
#          Ticket    Fare Cabin Embarked
# 4995  TKT004996   27.12   NaN        S
# 4996  TKT004997   93.21   B45        S
# 4997  TKT004998  178.97   A10        Q
# 4998  TKT004999   12.14   NaN        S
# 4999  TKT005000   79.46   E31        C

# %%
print(df.dtypes)
print()
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
print("Shape :", df.shape)
print()
# Out:
# Shape : (5000, 12)

# %%
print("Columns:", df.columns)
print()
# Out:
# Columns: Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
print("Information: ")
print(df.info())
print()
# Out:
# Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  5000 non-null   int64
#  1   Survived     5000 non-null   int64
#  2   Pclass       5000 non-null   int64
#  3   Name         5000 non-null   str
#  4   Sex          5000 non-null   str
#  5   Age          4706 non-null   float64
#  6   SibSp        5000 non-null   int64
#  7   Parch        5000 non-null   int64
#  8   Ticket       5000 non-null   str
#  9   Fare         5000 non-null   float64
#  10  Cabin        2080 non-null   str
#  11  Embarked     5000 non-null   str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 468.9 KB
# None

# %%
print("Statistical Summary:")
display(df.describe())
# Out:
# Statistical Summary:
#        PassengerId     Survived       Pclass          Age       SibSp  \
# count  5000.000000  5000.000000  5000.000000  4706.000000  5000.00000
# mean   2500.500000     0.583400     1.980800    40.895325     2.02700
# std    1443.520003     0.493045     0.823752    22.781673     1.42277
# min       1.000000     0.000000     1.000000     1.000000     0.00000
# 25%    1250.750000     0.000000     1.000000    21.400000     1.00000
# 50%    2500.500000     1.000000     2.000000    41.000000     2.00000
# 75%    3750.250000     1.000000     3.000000    61.000000     3.00000
# max    5000.000000     1.000000     3.000000    80.000000     4.00000
#
#              Parch         Fare
# count  5000.000000  5000.000000
# mean      1.509400    75.426534
# std       1.135152    65.913301
# min       0.000000     5.000000
# 25%       0.000000    27.097500
# 50%       2.000000    51.260000
# 75%       3.000000   105.902500
# max       3.000000   249.960000

# %% [markdown]
# * Dataframe Operation

# %%
df['Name']
# Out:
# 0            John 1
# 1            John 2
# 2            John 3
# 3         William 4
# 4          Olivia 5
#            ...
# 4995      Liam 4996
# 4996       Mia 4997
# 4997     Alice 4998
# 4998      Emma 4999
# 4999    Sophia 5000
# Name: Name, Length: 5000, dtype: str

# %%
df[df['Age'] > 50]
# Out:
#       PassengerId  Survived  Pclass         Name     Sex   Age  SibSp  Parch  \
# 1               2         0       3       John 2    male  52.3      1      3
# 2               3         1       1       John 3  female  61.3      3      0
# 3               4         0       3    William 4    male  50.7      1      2
# 5               6         1       2        Ava 6  female  74.1      0      2
# 6               7         1       1      Alice 7  female  75.5      1      2
# ...           ...       ...     ...          ...     ...   ...    ...    ...
# 4993         4994         1       1  Robert 4994    male  59.2      1      1
# 4994         4995         1       2  Robert 4995  female  71.8      3      3
# 4995         4996         0       3    Liam 4996    male  76.2      1      0
# 4997         4998         1       1   Alice 4998    male  52.3      0      1
# 4998         4999         1       3    Emma 4999  female  58.8      4      3
#
#          Ticket    Fare Cabin Embarked
# 1     TKT000002   33.33   NaN        C
# 2     TKT000003  125.99   NaN        C
# 3     TKT000004    7.43   NaN        S
# 5     TKT000006   39.46   NaN        C
# 6     TKT000007  181.09   C23        Q
# ...         ...     ...   ...      ...
# 4993  TKT004994  226.20   NaN        S
# 4994  TKT004995   59.37   NaN        Q
# 4995  TKT004996   27.12   NaN        S
# 4997  TKT004998  178.97   A10        Q
# 4998  TKT004999   12.14   NaN        S
#
# [1824 rows x 12 columns]

# %%
df.sort_values(by='Fare', ascending=False)
# Out:
#       PassengerId  Survived  Pclass          Name     Sex   Age  SibSp  Parch  \
# 3991         3992         1       1  Michael 3992  female  42.9      1      1
# 4178         4179         0       1     Liam 4179    male  19.8      3      3
# 4786         4787         0       1    James 4787    male  73.2      3      2
# 260           261         0       1       Mia 261    male  34.4      0      0
# 637           638         1       1   Michael 638  female  23.3      4      1
# ...           ...       ...     ...           ...     ...   ...    ...    ...
# 2136         2137         0       3     Emma 2137    male  22.4      4      1
# 2660         2661         0       3  William 2661    male  79.2      0      2
# 1421         1422         1       3    Alice 1422  female  60.5      3      0
# 3646         3647         1       3    Alice 3647  female  67.2      2      1
# 3882         3883         1       3     Noah 3883    male  57.6      1      0
#
#          Ticket    Fare Cabin Embarked
# 3991  TKT003992  249.96   A10        C
# 4178  TKT004179  249.94   A10        S
# 4786  TKT004787  249.69   NaN        S
# 260   TKT000261  249.45   NaN        C
# 637   TKT000638  249.37   A10        C
# ...         ...     ...   ...      ...
# 2136  TKT002137    5.14   NaN        S
# 2660  TKT002661    5.11   NaN        Q
# 1421  TKT001422    5.04   NaN        Q
# 3646  TKT003647    5.02   NaN        Q
# 3882  TKT003883    5.00   NaN        Q
#
# [5000 rows x 12 columns]

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 3    1032
# 4    1032
# 0    1001
# 2     976
# 1     959
# Name: count, dtype: int64

# %%
print("Maximum Age: " ,df["Age"].max())
print("Minimum Age:",df["Age"].min())
print("Avarage Age: ",df["Age"].mean())
# Out:
# Maximum Age:  80.0
# Minimum Age: 1.0
# Avarage Age:  40.89532511687208

# %% [markdown]
# * Check Missing Values

# %%
print(df.isnull().sum())
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             294
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          2920
# Embarked          0
# dtype: int64

# %% [markdown]
# * Fill Missig Values

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex   Age  SibSp  Parch  \
# 0            1         1       1     John 1    male  20.3      0      1
# 1            2         0       3     John 2    male  52.3      1      3
# 2            3         1       1     John 3  female  61.3      3      0
# 3            4         0       3  William 4    male  50.7      1      2
# 4            5         1       1   Olivia 5    male  36.8      1      1
#
#       Ticket    Fare Cabin Embarked
# 0  TKT000001   70.50   A10        S
# 1  TKT000002   33.33   NaN        C
# 2  TKT000003  125.99   NaN        C
# 3  TKT000004    7.43   NaN        S
# 4  TKT000005  121.05   A10        S

# %% [markdown]
# * Average Fare by Passenger Class

# %%
fare = df.groupby("Pclass")["Fare"].mean()

plt.figure(figsize=(8,5))
plt.plot(fare.index, fare.values, marker="o",color="orange")
plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")

plt.show()

# %% [markdown]
# * Average Age by Passenger Class

# %%
age = df.groupby("Pclass")["Age"].mean()

plt.figure(figsize=(8,5))
plt.plot(age.index, age.values, marker="o",color="green")
plt.title("Average Age by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Age")

plt.show()

# %% [markdown]
# * Survival Count

# %%
survival = df["Survived"].value_counts()

plt.figure(figsize=(8,5))
plt.bar(survival.index.astype(str), survival.values,color="brown")
plt.title("Survival Count")
plt.xlabel("Survived")
plt.ylabel("Passengers")

plt.show()

# %% [markdown]
# * Passengers by Gender

# %%
gender = df["Sex"].value_counts()

plt.figure(figsize=(6,5))
plt.bar(gender.index, gender.values,color="purple")
plt.title("Passengers by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# * Survival Distribution

# %%
survival = df["Survived"].value_counts()

plt.figure(figsize=(8,8))
plt.pie( survival, labels=["Not Survived","Survived"], autopct="%1.1f%%", startangle=90)
plt.title("Survival Distribution")

plt.show()

# %% [markdown]
# * Age vs Fare

# %%
plt.figure(figsize=(10,5))
plt.scatter(df["Age"].head(500), df["Fare"].head(500),c=np.random.rand(500),cmap="magma",s=100)

plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")

plt.show()

# %% [markdown]
# * Correlation Heatmap of Titanic Dataset

# %%
plt.figure(figsize=(10,6))
sns.heatmap( df.corr(numeric_only=True), annot=True, cmap="Oranges", fmt=".2f", linewidths=1, linecolor="White")
plt.title("Correlation Heatmap of Titanic Dataset")

plt.show()

# %%
df["Survival Rate"] = (df["Survived"] * 100).round(2)
df[["Survived", "Survival Rate"]].head()
# Out:
#    Survived  Survival Rate
# 0         1            100
# 1         0              0
# 2         1            100
# 3         0              0
# 4         1            100

# %%
df["Death Rate"] = ((1 - df["Survived"]) * 100).round(2)
df[["Survived", "Death Rate"]].head()
# Out:
#    Survived  Death Rate
# 0         1           0
# 1         0         100
# 2         1           0
# 3         0         100
# 4         1           0
