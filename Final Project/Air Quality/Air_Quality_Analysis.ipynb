# %% [markdown]
# --------------- Air Quality Analysis ---------------

# %% [markdown]
# * Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * Load Dataset

# %%
df = pd.read_csv('Air_Quality_Analysis.csv')
df.head()
# Out:
#    Station_ID       City  PM2.5   PM10    NO2   SO2    CO  Ozone  Temperature  \
# 0           1     Mumbai   24.1  274.1   59.0  89.2  4.45  140.1         43.5
# 1           2      Surat  293.8  246.8   20.5  49.3  2.10   64.3         29.4
# 2           3      Surat   63.6  217.5  106.4  37.2  4.14  149.5         24.9
# 3           4    Chennai  276.2   21.0   41.4   9.1  0.94  124.0         40.9
# 4           5  Bengaluru  248.9  272.1   15.8  92.3  3.41  158.9         26.0
#
#    Humidity  Wind_Speed    AQI  AQI_Category Weather
# 0      70.0         5.3  119.0      Moderate   Foggy
# 1      72.0        17.2  187.0      Moderate   Foggy
# 2      92.0        18.0  129.0  Satisfactory  Cloudy
# 3      57.0        11.3  112.0  Satisfactory   Rainy
# 4      84.0         4.2  178.0          Good   Sunny

# %% [markdown]
# * Dataset Information

# %%
df.head()
# Out:
#    Station_ID       City  PM2.5   PM10    NO2   SO2    CO  Ozone  Temperature  \
# 0           1     Mumbai   24.1  274.1   59.0  89.2  4.45  140.1         43.5
# 1           2      Surat  293.8  246.8   20.5  49.3  2.10   64.3         29.4
# 2           3      Surat   63.6  217.5  106.4  37.2  4.14  149.5         24.9
# 3           4    Chennai  276.2   21.0   41.4   9.1  0.94  124.0         40.9
# 4           5  Bengaluru  248.9  272.1   15.8  92.3  3.41  158.9         26.0
#
#    Humidity  Wind_Speed    AQI  AQI_Category Weather
# 0      70.0         5.3  119.0      Moderate   Foggy
# 1      72.0        17.2  187.0      Moderate   Foggy
# 2      92.0        18.0  129.0  Satisfactory  Cloudy
# 3      57.0        11.3  112.0  Satisfactory   Rainy
# 4      84.0         4.2  178.0          Good   Sunny

# %%
df.tail()
# Out:
#       Station_ID     City  PM2.5   PM10   NO2   SO2    CO  Ozone  Temperature  \
# 4995        4996  Kolkata  246.2  229.9  10.2  82.8  1.26   13.6         12.0
# 4996        4997  Kolkata  171.3  133.9  85.9  82.4  1.47   66.9         15.4
# 4997        4998    Surat  241.6  298.0  71.5  59.0  2.32  194.5         22.9
# 4998        4999   Mumbai  158.8  157.7  91.3  31.6  2.16   44.9         41.6
# 4999        5000  Kolkata  291.2  209.4  17.2  95.8  1.85   50.6         31.9
#
#       Humidity  Wind_Speed    AQI AQI_Category Weather
# 4995      81.0         2.4  162.0         Good  Cloudy
# 4996      50.0         7.8  130.0         Good   Sunny
# 4997      79.0        18.1  203.0         Good   Rainy
# 4998      34.0         6.8  135.0         Poor  Cloudy
# 4999      92.0        12.3  172.0         Good   Sunny

# %%
print(df.dtypes)
print()
# Out:
# Station_ID        int64
# City                str
# PM2.5           float64
# PM10            float64
# NO2             float64
# SO2             float64
# CO              float64
# Ozone           float64
# Temperature     float64
# Humidity        float64
# Wind_Speed      float64
# AQI             float64
# AQI_Category        str
# Weather             str
# dtype: object

# %%
print("Shape :", df.shape)
print()
# Out:
# Shape : (5000, 14)

# %%
print("Columns:", df.columns)
print()
# Out:
# Columns: Index(['Station_ID', 'City', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'Ozone',
#        'Temperature', 'Humidity', 'Wind_Speed', 'AQI', 'AQI_Category',
#        'Weather'],
#       dtype='str')

# %%
print("Information: ")
print(df.info())
print()
# Out:
# Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Station_ID    5000 non-null   int64
#  1   City          5000 non-null   str
#  2   PM2.5         4900 non-null   float64
#  3   PM10          4900 non-null   float64
#  4   NO2           4900 non-null   float64
#  5   SO2           5000 non-null   float64
#  6   CO            5000 non-null   float64
#  7   Ozone         5000 non-null   float64
#  8   Temperature   4900 non-null   float64
#  9   Humidity      4900 non-null   float64
#  10  Wind_Speed    5000 non-null   float64
#  11  AQI           4900 non-null   float64
#  12  AQI_Category  5000 non-null   str
#  13  Weather       5000 non-null   str
# dtypes: float64(10), int64(1), str(3)
# memory usage: 547.0 KB
# None

# %%
print("Statistical Summary:")
display(df.describe())
# Out:
# Statistical Summary:
#         Station_ID        PM2.5         PM10          NO2          SO2  \
# count  5000.000000  4900.000000  4900.000000  4900.000000  5000.000000
# mean   2500.500000   153.991082   204.635898    93.102306    50.695360
# std    1443.520003    84.704617   112.248387    50.545218    28.292229
# min       1.000000     5.000000    10.200000     5.000000     2.000000
# 25%    1250.750000    79.375000   108.075000    50.100000    26.200000
# 50%    2500.500000   156.600000   205.600000    93.300000    50.300000
# 75%    3750.250000   226.500000   301.700000   137.425000    74.500000
# max    5000.000000   299.900000   399.800000   180.000000    99.900000
#
#                 CO        Ozone  Temperature     Humidity   Wind_Speed  \
# count  5000.000000  5000.000000  4900.000000  4900.000000  5000.000000
# mean      2.597108   103.695340    27.737612    57.258163    10.113960
# std       1.383742    56.458941     9.916270    21.872109     5.606968
# min       0.200000     5.000000    10.000000    20.000000     0.500000
# 25%       1.390000    55.775000    19.300000    38.000000     5.300000
# 50%       2.620000   104.000000    27.800000    57.000000    10.000000
# 75%       3.810000   152.350000    36.300000    76.000000    14.900000
# max       5.000000   199.900000    45.000000    95.000000    20.000000
#
#                AQI
# count  4900.000000
# mean    150.022449
# std      49.049657
# min      23.000000
# 25%     114.750000
# 50%     149.000000
# 75%     186.000000
# max     283.000000

# %% [markdown]
# * Dataframe Operations

# %%
df["City"]
# Out:
# 0          Mumbai
# 1           Surat
# 2           Surat
# 3         Chennai
# 4       Bengaluru
#           ...
# 4995      Kolkata
# 4996      Kolkata
# 4997        Surat
# 4998       Mumbai
# 4999      Kolkata
# Name: City, Length: 5000, dtype: str

# %%
df[df["Wind_Speed"] < 10]
# Out:
#       Station_ID       City  PM2.5   PM10    NO2   SO2    CO  Ozone  \
# 0              1     Mumbai   24.1  274.1   59.0  89.2  4.45  140.1
# 4              5  Bengaluru  248.9  272.1   15.8  92.3  3.41  158.9
# 5              6    Kolkata  183.3  339.6  140.2   8.0  3.39  180.9
# 7              8  Ahmedabad  178.2   30.5   31.0  86.1  0.26  187.6
# 8              9     Mumbai  292.6  367.4  135.9  20.7  1.94  102.5
# ...          ...        ...    ...    ...    ...   ...   ...    ...
# 4993        4994       Pune  102.6  141.8  131.8  84.7  0.87  196.1
# 4994        4995  Bengaluru   18.9   40.2  154.2  83.6  2.31   24.5
# 4995        4996    Kolkata  246.2  229.9   10.2  82.8  1.26   13.6
# 4996        4997    Kolkata  171.3  133.9   85.9  82.4  1.47   66.9
# 4998        4999     Mumbai  158.8  157.7   91.3  31.6  2.16   44.9
#
#       Temperature  Humidity  Wind_Speed    AQI AQI_Category Weather
# 0            43.5      70.0         5.3  119.0     Moderate   Foggy
# 4            26.0      84.0         4.2  178.0         Good   Sunny
# 5            16.9      92.0         8.0  221.0         Good  Cloudy
# 7            40.9      45.0         1.3   79.0       Severe   Foggy
# 8            38.5      47.0         7.8  265.0         Good  Cloudy
# ...           ...       ...         ...    ...          ...     ...
# 4993         24.6      62.0         9.6  125.0    Very Poor  Cloudy
# 4994         21.7      95.0         0.8   71.0         Poor   Foggy
# 4995         12.0      81.0         2.4  162.0         Good  Cloudy
# 4996         15.4      50.0         7.8  130.0         Good   Sunny
# 4998         41.6      34.0         6.8  135.0         Poor  Cloudy
#
# [2491 rows x 14 columns]

# %%
df.sort_values(by="Ozone", ascending=True)
# Out:
#       Station_ID       City  PM2.5   PM10    NO2   SO2    CO  Ozone  \
# 2827        2828      Surat   17.1  374.0  172.1  44.0  3.14    5.0
# 3235        3236  Hyderabad  148.6  266.2  129.4  39.5  3.57    5.0
# 1382        1383      Surat   30.2  385.5  160.4  84.0  4.21    5.0
# 170          171    Chennai   58.6  134.5   56.2  44.6  4.33    5.0
# 4833        4834  Bengaluru   80.7  191.7   33.9  34.5  3.02    5.1
# ...          ...        ...    ...    ...    ...   ...   ...    ...
# 700          701  Bengaluru   61.7  163.7  153.7  79.1  3.76  199.8
# 1593        1594      Surat  114.1  233.8  168.3  30.0  4.05  199.9
# 1794        1795      Surat  102.6  120.9    8.1  85.5  3.85  199.9
# 1598        1599    Chennai   37.5  286.3   68.7  63.4  4.87  199.9
# 3456        3457    Kolkata  182.9   93.9   83.6  84.8  0.60  199.9
#
#       Temperature  Humidity  Wind_Speed    AQI AQI_Category Weather
# 2827         17.3      37.0         9.8  187.0       Severe   Foggy
# 3235         45.0      31.0         3.6  181.0     Moderate   Foggy
# 1382         40.3      35.0         8.7  192.0     Moderate  Cloudy
# 170          13.1      69.0        14.7   83.0         Good   Rainy
# 4833         31.3      69.0        11.4  102.0         Good   Rainy
# ...           ...       ...         ...    ...          ...     ...
# 700          43.6      65.0        12.7  126.0       Severe  Cloudy
# 1593         42.8      74.0         5.2  172.0       Severe  Cloudy
# 1794         33.9      62.0        17.4   77.0         Good   Sunny
# 1598         31.3      82.0         8.0  130.0         Good  Cloudy
# 3456         38.0      21.0        14.8  120.0         Poor  Cloudy
#
# [5000 rows x 14 columns]

# %%
df["Temperature"].value_counts()
# Out:
# Temperature
# 19.9    27
# 18.8    25
# 17.5    23
# 24.3    22
# 37.9    22
#         ..
# 45.0     5
# 20.4     5
# 12.5     5
# 15.5     5
# 44.0     4
# Name: count, Length: 351, dtype: int64

# %%
print("Maximum Ozone: " ,df["Ozone"].max())
print("Maximum Temperature:",df["Temperature"].max())
print("Maximum Wind_Speed: ",df["Wind_Speed"].max())
# Out:
# Maximum Ozone:  199.9
# Maximum Temperature: 45.0
# Maximum Wind_Speed:  20.0

# %%
print("Minimum Ozone: " ,df["Ozone"].min())
print("Minimum Temperature:",df["Temperature"].min())
print("Minimum Wind_Speed: ",df["Wind_Speed"].min())
# Out:
# Minimum Ozone:  5.0
# Minimum Temperature: 10.0
# Minimum Wind_Speed:  0.5

# %% [markdown]
# * Check Missing Values

# %%
print(df.isnull().sum())
# Out:
# Station_ID        0
# City              0
# PM2.5           100
# PM10            100
# NO2             100
# SO2               0
# CO                0
# Ozone             0
# Temperature     100
# Humidity        100
# Wind_Speed        0
# AQI             100
# AQI_Category      0
# Weather           0
# dtype: int64

# %% [markdown]
# * Fill Missing Values

# %%
df['PM2.5'] = df['PM2.5'].fillna(df['PM2.5'].mean())
df['PM10'] = df['PM10'].fillna(df['PM10'].mean())
df['NO2'] = df['NO2'].fillna(df['NO2'].mean())
df['Temperature'] = df['Temperature'].fillna(df['Temperature'].mean())
df['Humidity'] = df['Humidity'].fillna(df['Humidity'].mean())
df['AQI'] = df['AQI'].fillna(df['AQI'].mean())

df.tail()
# Out:
#       Station_ID     City  PM2.5   PM10   NO2   SO2    CO  Ozone  Temperature  \
# 4995        4996  Kolkata  246.2  229.9  10.2  82.8  1.26   13.6         12.0
# 4996        4997  Kolkata  171.3  133.9  85.9  82.4  1.47   66.9         15.4
# 4997        4998    Surat  241.6  298.0  71.5  59.0  2.32  194.5         22.9
# 4998        4999   Mumbai  158.8  157.7  91.3  31.6  2.16   44.9         41.6
# 4999        5000  Kolkata  291.2  209.4  17.2  95.8  1.85   50.6         31.9
#
#       Humidity  Wind_Speed    AQI AQI_Category Weather
# 4995      81.0         2.4  162.0         Good  Cloudy
# 4996      50.0         7.8  130.0         Good   Sunny
# 4997      79.0        18.1  203.0         Good   Rainy
# 4998      34.0         6.8  135.0         Poor  Cloudy
# 4999      92.0        12.3  172.0         Good   Sunny

# %% [markdown]
# * Average AQI by City

# %%
city_aqi = df.groupby("City")["AQI"].mean()

plt.figure(figsize=(10,5))
plt.plot(city_aqi.index, city_aqi.values, marker='o', linewidth=2,color="red")
plt.title("Average AQI by City")
plt.xlabel("City")
plt.ylabel("Average AQI")

plt.show()

# %% [markdown]
# * Average PM2.5 by City

# %%
pm25 = df.groupby("City")["PM2.5"].mean()

plt.figure(figsize=(10,5))
plt.bar(pm25.index, pm25.values, color="skyblue")
plt.title("Average PM2.5 by City")
plt.xlabel("City")
plt.ylabel("PM2.5")

plt.show()

# %% [markdown]
# * AQI Category Distribution

# %%
aqi = df["AQI_Category"].value_counts()

plt.figure(figsize=(6,6))
plt.pie(aqi, labels=aqi.index, autopct="%1.1f%%", startangle=90)
plt.title("AQI Category Distribution")

plt.show()

# %% [markdown]
# * PM2.5 vs AQI

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["PM2.5"].head(500), df["AQI"].head(500), c=np.random.rand(500),cmap="plasma", s=100)
plt.title("PM2.5 vs AQI")
plt.xlabel("PM2.5")
plt.ylabel("AQI")

plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")

plt.show()
