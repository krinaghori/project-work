# %% [markdown]
# --------------- COVID-19 DATASET ANALYSIS ---------------

# %% [markdown]
# * Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * Load Dataset

# %%
df = pd.read_csv('COVID19_Dataset.csv')
df.head()
# Out:
#          Date       Country         Region     Cases  Recovered  Deaths  \
# 0  2022-12-01  South Africa         Africa  111094.0    92389.0  2096.0
# 1  2022-02-26            UK         Europe  322424.0   259015.0  1893.0
# 2  2021-09-04         Italy         Europe    5547.0     4068.0    69.0
# 3  2020-07-30  South Africa         Africa   36178.0    23714.0  1169.0
# 4  2022-02-10        Canada  North America  122844.0    92714.0  6088.0
#
#    Active  NewCases  NewDeaths  Lockdown  Vaccine
# 0   16609    1379.0       73.0      55.8     11.9
# 1   61516    3542.0       50.0      50.6     97.0
# 2    1410    4301.0       80.0      73.8     54.4
# 3   11295    2138.0      100.0      96.7      8.0
# 4   24042    2768.0       58.0      11.7     75.2

# %% [markdown]
# * Dataset Information

# %%
df.head()
# Out:
#          Date       Country         Region     Cases  Recovered  Deaths  \
# 0  01/12/2022  South Africa         Africa  111094.0    92389.0  2096.0
# 1  26/02/2022            UK         Europe  322424.0   259015.0  1893.0
# 2  04/09/2021         Italy         Europe    5547.0     4068.0    69.0
# 3  30/07/2020  South Africa         Africa   36178.0    23714.0  1169.0
# 4  10/02/2022        Canada  North America  122844.0    92714.0  6088.0
#
#    Active  NewCases  NewDeaths  Lockdown  Vaccine  Recovery Rate  Death Rate
# 0   16609    1379.0       73.0      55.8     11.9      83.162907    1.886691
# 1   61516    3542.0       50.0      50.6     97.0      80.333660    0.587115
# 2    1410    4301.0       80.0      73.8     54.4      73.336939    1.243916
# 3   11295    2138.0      100.0      96.7      8.0      65.548123    3.231246
# 4   24042    2768.0       58.0      11.7     75.2      75.472958    4.955879

# %%
df.tail()
# Out:
#             Date       Country  Region     Cases  Recovered   Deaths  Active  \
# 4995  19/06/2021         India    Asia   92696.0    78754.0   3016.0   10926
# 4996  02/04/2021       Germany  Europe  291254.0   225913.0  10109.0   55232
# 4997  07/02/2022         Japan    Asia  424998.0   260534.0   7634.0  156830
# 4998  08/07/2020  South Africa  Africa  117475.0    78691.0    961.0   37823
# 4999  19/05/2021         Japan    Asia   67930.0    47780.0    187.0   19963
#
#       NewCases  NewDeaths  Lockdown  Vaccine  Recovery Rate  Death Rate
# 4995    4164.0       78.0      29.9     36.1      84.959437    3.253646
# 4996     222.0       73.0      73.7     96.8      77.565630    3.470854
# 4997     553.0      100.0      69.8     91.3      61.302406    1.796244
# 4998    3540.0       93.0      52.2     37.3      66.985316    0.818046
# 4999     228.0       37.0      47.0     66.5      70.337112    0.275283

# %%
print(df.dtypes)
print()
# Out:
# Date                 str
# Country              str
# Region               str
# Cases            float64
# Recovered        float64
# Deaths           float64
# Active             int64
# NewCases         float64
# NewDeaths        float64
# Lockdown         float64
# Vaccine          float64
# Recovery Rate    float64
# Death Rate       float64
# dtype: object

# %%
print("Shape :", df.shape)
print()
# Out:
# Shape : (5000, 13)

# %%
print("Columns:", df.columns)
print()
# Out:
# Columns: Index(['Date', 'Country', 'Region', 'Cases', 'Recovered', 'Deaths', 'Active',
#        'NewCases', 'NewDeaths', 'Lockdown', 'Vaccine'],
#       dtype='str')

# %%
print("Information: ")
print(df.info())
print()
# Out:
# Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5000 non-null   str
#  1   Country    5000 non-null   str
#  2   Region     5000 non-null   str
#  3   Cases      4920 non-null   float64
#  4   Recovered  4920 non-null   float64
#  5   Deaths     4920 non-null   float64
#  6   Active     5000 non-null   int64
#  7   NewCases   4920 non-null   float64
#  8   NewDeaths  4920 non-null   float64
#  9   Lockdown   4920 non-null   float64
#  10  Vaccine    4920 non-null   float64
# dtypes: float64(7), int64(1), str(3)
# memory usage: 429.8 KB
# None

# %%
print("Statistical Summary:")
display(df.describe())
# Out:
# Statistical Summary:
#                Cases      Recovered        Deaths         Active     NewCases  \
# count    4920.000000    4920.000000   4920.000000    5000.000000  4920.000000
# mean   252188.178252  187570.270732   6374.293089   58834.415600  2494.867886
# std    143888.758462  114080.068764   5517.625039   52876.239851  1449.161447
# min       355.000000     289.000000      0.000000       0.000000     0.000000
# 25%    126305.000000   91311.750000   1823.750000   15387.500000  1230.750000
# 50%    253857.500000  181606.500000   4803.500000   43429.000000  2492.000000
# 75%    378110.750000  269638.500000   9728.500000   89496.750000  3780.000000
# max    499985.000000  482823.000000  24545.000000  238300.000000  5000.000000
#
#          NewDeaths     Lockdown      Vaccine
# count  4920.000000  4920.000000  4920.000000
# mean     50.548171    54.981220    50.076077
# std      29.407909    25.876545    28.769927
# min       0.000000    10.000000     0.000000
# 25%      25.000000    32.600000    25.800000
# 50%      51.000000    55.300000    49.900000
# 75%      76.000000    77.525000    75.025000
# max     100.000000   100.000000   100.000000

# %% [markdown]
# * Dataframe Operations

# %%
df["Cases"]
# Out:
# 0       111094.0
# 1       322424.0
# 2         5547.0
# 3        36178.0
# 4       122844.0
#           ...
# 4995     92696.0
# 4996    291254.0
# 4997    424998.0
# 4998    117475.0
# 4999     67930.0
# Name: Cases, Length: 5000, dtype: float64

# %%
df[df["Cases"] > 10000]
# Out:
#             Date       Country         Region     Cases  Recovered   Deaths  \
# 0     01/12/2022  South Africa         Africa  111094.0    92389.0   2096.0
# 1     26/02/2022            UK         Europe  322424.0   259015.0   1893.0
# 3     30/07/2020  South Africa         Africa   36178.0    23714.0   1169.0
# 4     10/02/2022        Canada  North America  122844.0    92714.0   6088.0
# 6     11/01/2021            UK         Europe  495406.0   301500.0   6083.0
# ...          ...           ...            ...       ...        ...      ...
# 4995  19/06/2021         India           Asia   92696.0    78754.0   3016.0
# 4996  02/04/2021       Germany         Europe  291254.0   225913.0  10109.0
# 4997  07/02/2022         Japan           Asia  424998.0   260534.0   7634.0
# 4998  08/07/2020  South Africa         Africa  117475.0    78691.0    961.0
# 4999  19/05/2021         Japan           Asia   67930.0    47780.0    187.0
#
#       Active  NewCases  NewDeaths  Lockdown  Vaccine  Recovery Rate  \
# 0      16609    1379.0       73.0      55.8     11.9      83.162907
# 1      61516    3542.0       50.0      50.6     97.0      80.333660
# 3      11295    2138.0      100.0      96.7      8.0      65.548123
# 4      24042    2768.0       58.0      11.7     75.2      75.472958
# 6     187823    2715.0       21.0      58.6     73.6      60.859174
# ...      ...       ...        ...       ...      ...            ...
# 4995   10926    4164.0       78.0      29.9     36.1      84.959437
# 4996   55232     222.0       73.0      73.7     96.8      77.565630
# 4997  156830     553.0      100.0      69.8     91.3      61.302406
# 4998   37823    3540.0       93.0      52.2     37.3      66.985316
# 4999   19963     228.0       37.0      47.0     66.5      70.337112
#
#       Death Rate
# 0       1.886691
# 1       0.587115
# 3       3.231246
# 4       4.955879
# 6       1.227882
# ...          ...
# 4995    3.253646
# 4996    3.470854
# 4997    1.796244
# 4998    0.818046
# 4999    0.275283
#
# [4908 rows x 13 columns]

# %%
df.sort_values(by="Vaccine", ascending=False)
# Out:
#             Date       Country         Region     Cases  Recovered   Deaths  \
# 2453  11/11/2022           USA  North America  166965.0   140243.0   4590.0
# 2870  16/03/2021     Australia        Oceania   26350.0    24942.0    198.0
# 3229  21/09/2020           USA  North America  239506.0   145213.0  11193.0
# 4138  01/05/2023            UK         Europe  261747.0   174662.0    946.0
# 4094  28/03/2022         India           Asia  266957.0   148705.0  10555.0
# ...          ...           ...            ...       ...        ...      ...
# 4571  10/02/2023     Australia        Oceania  233227.0   124000.0   9126.0
# 4577  24/05/2020  South Africa         Africa    9356.0     5354.0    249.0
# 4614  10/04/2020         India           Asia  297015.0   230350.0   3580.0
# 4636  20/12/2022  South Africa         Africa  343865.0   196210.0   9176.0
# 4953  12/12/2021        Canada  North America   65843.0    32976.0   2745.0
#
#       Active  NewCases  NewDeaths  Lockdown  Vaccine  Recovery Rate  \
# 2453   22132    2422.0       55.0      92.8    100.0      83.995448
# 2870    1210    2709.0       76.0      70.8     99.9      94.656546
# 3229   83100    1352.0       25.0      39.3     99.9      60.630214
# 4138   86139     762.0        6.0      87.1     99.9      66.729323
# 4094  107697     393.0       92.0      25.7     99.9      55.703728
# ...      ...       ...        ...       ...      ...            ...
# 4571  100101    2974.0       46.0      94.4      NaN      53.167086
# 4577    3753    4129.0       95.0      59.2      NaN      57.225310
# 4614   63085     398.0        3.0      13.1      NaN      77.555006
# 4636  138479    3356.0       13.0      86.6      NaN      57.060184
# 4953   30122    2842.0        9.0      50.9      NaN      50.082773
#
#       Death Rate
# 2453    2.749079
# 2870    0.751423
# 3229    4.673369
# 4138    0.361418
# 4094    3.953820
# ...          ...
# 4571    3.912926
# 4577    2.661394
# 4614    1.205326
# 4636    2.668489
# 4953    4.169008
#
# [5000 rows x 13 columns]

# %%
df["Deaths"].value_counts()
# Out:
# Deaths
# 6374.293089    80
# 20.000000       8
# 198.000000      6
# 69.000000       4
# 0.000000        4
#                ..
# 550.000000      1
# 3040.000000     1
# 3016.000000     1
# 7634.000000     1
# 961.000000      1
# Name: count, Length: 4151, dtype: int64

# %%
print("Maximum Cases: " ,df["Cases"].max())
print("Maximum Recovered:",df["Recovered"].max())
print("Maximum Deaths: ",df["Deaths"].max())
# Out:
# Maximum Cases:  499985.0
# Maximum Recovered: 482823.0
# Maximum Deaths:  24545.0

# %% [markdown]
# * Check Missing Values

# %%
print(df.isnull().sum())
# Out:
# Date          0
# Country       0
# Region        0
# Cases        80
# Recovered    80
# Deaths       80
# Active        0
# NewCases     80
# NewDeaths    80
# Lockdown     80
# Vaccine      80
# dtype: int64

# %% [markdown]
# * Fill Missing Values

# %%
df['Cases'] = df['Cases'].fillna(df['Cases'].mean())
df['Recovered'] = df['Recovered'].fillna(df['Recovered'].mean())
df['Deaths'] = df['Deaths'].fillna(df['Deaths'].mean())
df['NewCases'] = df['NewCases'].fillna(df['NewCases'].mean())
df['NewDeaths'] = df['NewDeaths'].fillna(df['NewDeaths'].mean())

df['Lockdown'] = df['Lockdown'].fillna(df['Lockdown'].mode()[0])

df.head()
# Out:
#          Date       Country         Region     Cases  Recovered  Deaths  \
# 0  2022-12-01  South Africa         Africa  111094.0    92389.0  2096.0
# 1  2022-02-26            UK         Europe  322424.0   259015.0  1893.0
# 2  2021-09-04         Italy         Europe    5547.0     4068.0    69.0
# 3  2020-07-30  South Africa         Africa   36178.0    23714.0  1169.0
# 4  2022-02-10        Canada  North America  122844.0    92714.0  6088.0
#
#    Active  NewCases  NewDeaths  Lockdown  Vaccine
# 0   16609    1379.0       73.0      55.8     11.9
# 1   61516    3542.0       50.0      50.6     97.0
# 2    1410    4301.0       80.0      73.8     54.4
# 3   11295    2138.0      100.0      96.7      8.0
# 4   24042    2768.0       58.0      11.7     75.2

# %% [markdown]
# * Convert Date Column

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%d/%m/%Y')

df.head()
# Out:
#          Date       Country         Region     Cases  Recovered  Deaths  \
# 0  01/12/2022  South Africa         Africa  111094.0    92389.0  2096.0
# 1  26/02/2022            UK         Europe  322424.0   259015.0  1893.0
# 2  04/09/2021         Italy         Europe    5547.0     4068.0    69.0
# 3  30/07/2020  South Africa         Africa   36178.0    23714.0  1169.0
# 4  10/02/2022        Canada  North America  122844.0    92714.0  6088.0
#
#    Active  NewCases  NewDeaths  Lockdown  Vaccine
# 0   16609    1379.0       73.0      55.8     11.9
# 1   61516    3542.0       50.0      50.6     97.0
# 2    1410    4301.0       80.0      73.8     54.4
# 3   11295    2138.0      100.0      96.7      8.0
# 4   24042    2768.0       58.0      11.7     75.2

# %% [markdown]
# * Spread of COVID-19 Over Time

# %%
daily_cases = df.groupby("Date")["Cases"].sum().head(100)

plt.figure(figsize=(12,5))
plt.plot(daily_cases)

plt.title("Spread of COVID-19 Over Time")
plt.xlabel("Date")
plt.ylabel("Cases")

plt.show()

# %% [markdown]
# * Recovery Trend

# %%
daily_recovery = df.groupby("Date")["Recovered"].sum().head(100)

plt.figure(figsize=(12,5))

plt.plot(daily_recovery,color="green")
plt.title("Recovery Trend")
plt.xlabel("Date")
plt.ylabel("Recovered Cases")

plt.show()

# %% [markdown]
# * Death Trend

# %%
daily_deaths = df.groupby("Date")["Deaths"].sum().head(100)

plt.figure(figsize=(12,5))
plt.plot(daily_deaths,color="red")
plt.title("Death Trend")
plt.xlabel("Date")
plt.ylabel("Deaths")

plt.show()

# %% [markdown]
# * Top 10 Countries with Highest Cases

# %%
top_country = df.groupby("Country")["Cases"].sum().sort_values(ascending=False).head(10)

top_country.plot(kind="bar",figsize=(10,5),color="yellow")
plt.title("Top 10 Countries by Confirmed Cases")
plt.xlabel("Country")
plt.ylabel("Confirmed Cases")

plt.show()

# %% [markdown]
# * Top 10 Region with Highest Cases

# %%
top_state = df.groupby("Region")["Cases"].sum().sort_values(ascending=False).head(10)

top_state.plot(kind="bar",figsize=(10,5),color="pink")
plt.title("Top Region by Confirmed Cases")
plt.xlabel("Region")
plt.ylabel("Confirmed Cases")

plt.show()

# %% [markdown]
# * Government Intervention (Lockdown)

# %%
lockdown = df.groupby("Lockdown")["Cases"].mean().head(10)

plt.figure(figsize=(8,8))
plt.pie(lockdown, labels=lockdown.index, autopct="%1.1f%%", startangle=90)
plt.title("Government Intervention vs Confirmed Cases")

plt.show()

# %% [markdown]
# * Vaccination Impact

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Vaccine"].head(500),df["Cases"].head(500), c=np.random.rand(500),cmap="viridis", s=100)
plt.title("Vaccination vs Confirmed Cases")
plt.xlabel("Vaccinated Population")
plt.ylabel("Confirmed Cases")

plt.show()

# %% [markdown]
# * Correlation Heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")

plt.title("Correlation Matrix")

plt.show()

# %% [markdown]
# * Recovery Rate

# %%
df["Recovery Rate"] = (df["Recovered"] / df["Cases"]) * 100

print()
print("Average Recovery Rate:- ",df["Recovery Rate"].mean())
print()
# Out:
# Average Recovery Rate:-  75.52377175292368

# %% [markdown]
# * Death Rate

# %%
df["Death Rate"] = (df["Deaths"] / df["Cases"]) * 100

print()
print("Average Death Rate:- ",df["Death Rate"].mean())
print()
# Out:
# Average Death Rate:-  2.8291535782533104
