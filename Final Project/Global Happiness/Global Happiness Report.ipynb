# %% [markdown]
# --------------- Global Happiness Report Analysis ---------------

# %% [markdown]
# * Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * Load Dataset

# %%
df = pd.read_csv('Global_Happiness_Report.csv')
df.head()
# Out:
#    Country         Region  GDP_Per_Capita  Social_Support  Life_Expectancy  \
# 0  Germany         Europe           1.963           0.951             79.9
# 1   Brazil        Oceania           2.467           0.396             80.2
# 2  Denmark        Oceania           2.407           0.529             75.3
# 3   France  South America           2.500           0.691             81.8
# 4      UAE        Oceania           2.152           0.795             81.4
#
#    Freedom  Generosity  Corruption_Perception  Unemployment_Rate  \
# 0    0.696       0.379                  0.421               14.5
# 1    0.609       0.465                  0.869               10.9
# 2    0.555       0.723                  0.038               16.2
# 3    0.351       0.160                  0.336                7.5
# 4    0.545       0.092                  0.832                3.0
#
#      Population  Happiness_Score  Happiness_Rank
# 0  1.372746e+09              8.0             1.0
# 1  2.846487e+08              8.0             2.0
# 2  1.286865e+09              8.0             3.0
# 3  4.601629e+08              8.0             4.0
# 4  1.374036e+09              8.0             5.0

# %% [markdown]
# * Dataset Information

# %%
df.head()
# Out:
#    Country         Region  GDP_Per_Capita  Social_Support  Life_Expectancy  \
# 0  Germany         Europe           1.963           0.951             79.9
# 1   Brazil        Oceania           2.467           0.396             80.2
# 2  Denmark        Oceania           2.407           0.529             75.3
# 3   France  South America           2.500           0.691             81.8
# 4      UAE        Oceania           2.152           0.795             81.4
#
#    Freedom  Generosity  Corruption_Perception  Unemployment_Rate  \
# 0    0.696       0.379                  0.421               14.5
# 1    0.609       0.465                  0.869               10.9
# 2    0.555       0.723                  0.038               16.2
# 3    0.351       0.160                  0.336                7.5
# 4    0.545       0.092                  0.832                3.0
#
#      Population  Happiness_Score  Happiness_Rank
# 0  1.372746e+09              8.0             1.0
# 1  2.846487e+08              8.0             2.0
# 2  1.286865e+09              8.0             3.0
# 3  4.601629e+08              8.0             4.0
# 4  1.374036e+09              8.0             5.0

# %%
df.tail()
# Out:
#       Country         Region  GDP_Per_Capita  Social_Support  Life_Expectancy  \
# 4995   Sweden  North America           0.615           0.320             52.5
# 4996       UK         Europe           0.379           0.478             54.6
# 4997   Brazil           Asia           0.381           0.571             50.4
# 4998    Nepal  North America           0.231           0.419             50.1
# 4999  Denmark  South America           0.455           0.313             54.0
#
#       Freedom  Generosity  Corruption_Perception  Unemployment_Rate  \
# 4995    0.299       0.773                  0.192                2.3
# 4996    0.223       0.482                  0.726               22.4
# 4997    0.211       0.352                  0.276               10.3
# 4998    0.862       0.006                  0.893                3.3
# 4999    0.244       0.635                  0.881               15.2
#
#         Population  Happiness_Score  Happiness_Rank
# 4995  1.250101e+09             3.35             NaN
# 4996  1.531577e+08             3.34          4997.0
# 4997  7.144415e+08             3.33          4998.0
# 4998  9.919874e+08             3.32          4999.0
# 4999  4.152710e+08             2.87          5000.0

# %%
print(df.dtypes)
print()
# Out:
# Country                      str
# Region                       str
# GDP_Per_Capita           float64
# Social_Support           float64
# Life_Expectancy          float64
# Freedom                  float64
# Generosity               float64
# Corruption_Perception    float64
# Unemployment_Rate        float64
# Population               float64
# Happiness_Score          float64
# Happiness_Rank           float64
# dtype: object

# %%
print("Shape :", df.shape)
print()
# Out:
# Shape : (5000, 12)

# %%
print("Columns:", df.columns)
print()
# Out:
# Columns: Index(['Country', 'Region', 'GDP_Per_Capita', 'Social_Support',
#        'Life_Expectancy', 'Freedom', 'Generosity', 'Corruption_Perception',
#        'Unemployment_Rate', 'Population', 'Happiness_Score', 'Happiness_Rank'],
#       dtype='str')

# %%
print("Information: ")
print(df.info())
print()
# Out:
# Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                5000 non-null   str
#  1   Region                 5000 non-null   str
#  2   GDP_Per_Capita         4900 non-null   float64
#  3   Social_Support         4900 non-null   float64
#  4   Life_Expectancy        4900 non-null   float64
#  5   Freedom                4900 non-null   float64
#  6   Generosity             5000 non-null   float64
#  7   Corruption_Perception  5000 non-null   float64
#  8   Unemployment_Rate      4950 non-null   float64
#  9   Population             4950 non-null   float64
#  10  Happiness_Score        4900 non-null   float64
#  11  Happiness_Rank         4950 non-null   float64
# dtypes: float64(10), str(2)
# memory usage: 468.9 KB
# None

# %%
print("Statistical Summary:")
display(df.describe())
# Out:
# Statistical Summary:
#        GDP_Per_Capita  Social_Support  Life_Expectancy      Freedom  \
# count     4900.000000     4900.000000      4900.000000  4900.000000
# mean         1.358989        0.646932        67.633265     0.601012
# std          0.658626        0.203414        10.104488     0.228388
# min          0.200000        0.300000        50.000000     0.200000
# 25%          0.795000        0.469000        58.900000     0.405000
# 50%          1.364000        0.643500        67.900000     0.605500
# 75%          1.915250        0.822000        76.500000     0.797000
# max          2.500000        1.000000        85.000000     0.999000
#
#         Generosity  Corruption_Perception  Unemployment_Rate    Population  \
# count  5000.000000            5000.000000        4950.000000  4.950000e+03
# mean      0.392116               0.450509          13.437657  6.988702e+08
# std       0.231445               0.259344           6.641911  4.076557e+08
# min       0.000000               0.001000           2.000000  5.095140e+05
# 25%       0.194000               0.226000           7.800000  3.474665e+08
# 50%       0.386500               0.457000          13.500000  7.040971e+08
# 75%       0.593000               0.673000          19.100000  1.048869e+09
# max       0.800000               0.900000          25.000000  1.399876e+09
#
#        Happiness_Score  Happiness_Rank
# count      4900.000000     4950.000000
# mean          6.406192     2501.142222
# std           1.134582     1443.614569
# min           2.870000        1.000000
# 25%           5.590000     1250.250000
# 50%           6.450000     2503.500000
# 75%           7.350000     3750.750000
# max           8.000000     5000.000000

# %% [markdown]
# * Dataframe Operations

# %%
df["Happiness_Rank"]
# Out:
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          5.0
#          ...
# 4995       NaN
# 4996    4997.0
# 4997    4998.0
# 4998    4999.0
# 4999    5000.0
# Name: Happiness_Rank, Length: 5000, dtype: float64

# %%
df[df["Life_Expectancy"] > 50]
# Out:
#       Country         Region  GDP_Per_Capita  Social_Support  Life_Expectancy  \
# 0     Germany         Europe           1.963           0.951             79.9
# 1      Brazil        Oceania           2.467           0.396             80.2
# 2     Denmark        Oceania           2.407           0.529             75.3
# 3      France  South America           2.500           0.691             81.8
# 4         UAE        Oceania           2.152           0.795             81.4
# ...       ...            ...             ...             ...              ...
# 4995   Sweden  North America           0.615           0.320             52.5
# 4996       UK         Europe           0.379           0.478             54.6
# 4997   Brazil           Asia           0.381           0.571             50.4
# 4998    Nepal  North America           0.231           0.419             50.1
# 4999  Denmark  South America           0.455           0.313             54.0
#
#       Freedom  Generosity  Corruption_Perception  Unemployment_Rate  \
# 0       0.696       0.379                  0.421               14.5
# 1       0.609       0.465                  0.869               10.9
# 2       0.555       0.723                  0.038               16.2
# 3       0.351       0.160                  0.336                7.5
# 4       0.545       0.092                  0.832                3.0
# ...       ...         ...                    ...                ...
# 4995    0.299       0.773                  0.192                2.3
# 4996    0.223       0.482                  0.726               22.4
# 4997    0.211       0.352                  0.276               10.3
# 4998    0.862       0.006                  0.893                3.3
# 4999    0.244       0.635                  0.881               15.2
#
#         Population  Happiness_Score  Happiness_Rank
# 0     1.372746e+09             8.00             1.0
# 1     2.846487e+08             8.00             2.0
# 2     1.286865e+09             8.00             3.0
# 3     4.601629e+08             8.00             4.0
# 4     1.374036e+09             8.00             5.0
# ...            ...              ...             ...
# 4995  1.250101e+09             3.35             NaN
# 4996  1.531577e+08             3.34          4997.0
# 4997  7.144415e+08             3.33          4998.0
# 4998  9.919874e+08             3.32          4999.0
# 4999  4.152710e+08             2.87          5000.0
#
# [4894 rows x 12 columns]

# %%
df.sort_values(by="Happiness_Rank", ascending=False)
# Out:
#       Country         Region  GDP_Per_Capita  Social_Support  Life_Expectancy  \
# 4999  Denmark  South America           0.455           0.313             54.0
# 4998    Nepal  North America           0.231           0.419             50.1
# 4997   Brazil           Asia           0.381           0.571             50.4
# 4996       UK         Europe           0.379           0.478             54.6
# 4994    Nepal         Europe           0.296           0.458             57.8
# ...       ...            ...             ...             ...              ...
# 4635  Denmark         Europe           0.582           0.382             58.6
# 4767       UK  South America             NaN             NaN              NaN
# 4801    India           Asia           0.369           0.800             51.4
# 4890  Finland         Europe           0.481           0.517             59.0
# 4995   Sweden  North America           0.615           0.320             52.5
#
#       Freedom  Generosity  Corruption_Perception  Unemployment_Rate  \
# 4999    0.244       0.635                  0.881               15.2
# 4998    0.862       0.006                  0.893                3.3
# 4997    0.211       0.352                  0.276               10.3
# 4996    0.223       0.482                  0.726               22.4
# 4994    0.227       0.116                  0.514               11.6
# ...       ...         ...                    ...                ...
# 4635    0.715       0.421                  0.013                7.6
# 4767      NaN       0.556                  0.101                2.4
# 4801    0.323       0.747                  0.277               15.0
# 4890    0.542       0.228                  0.253               17.1
# 4995    0.299       0.773                  0.192                2.3
#
#         Population  Happiness_Score  Happiness_Rank
# 4999  4.152710e+08             2.87          5000.0
# 4998  9.919874e+08             3.32          4999.0
# 4997  7.144415e+08             3.33          4998.0
# 4996  1.531577e+08             3.34          4997.0
# 4994  1.527968e+08             3.35          4995.0
# ...            ...              ...             ...
# 4635  1.257948e+09             4.65             NaN
# 4767  9.333995e+08              NaN             NaN
# 4801  5.016645e+07             4.30             NaN
# 4890  1.666498e+08             4.07             NaN
# 4995  1.250101e+09             3.35             NaN
#
# [5000 rows x 12 columns]

# %%
df["Happiness_Score"].value_counts()
# Out:
# Happiness_Score
# 8.00    568
# 7.28     22
# 6.28     22
# 7.03     21
# 6.18     21
#        ...
# 3.38      1
# 3.34      1
# 3.33      1
# 3.32      1
# 2.87      1
# Name: count, Length: 449, dtype: int64

# %%
print("Maximum Population: " ,df["Population"].max())
print("Maximum Happiness_Score:",df["Happiness_Score"].max())
print("Maximum Happiness_Rank: ",df["Happiness_Rank"].max())
# Out:
# Maximum Population:  1399876131.0
# Maximum Happiness_Score: 8.0
# Maximum Happiness_Rank:  5000.0

# %% [markdown]
# * Check Missing Values

# %%
print(df.isnull().sum())
# Out:
# Country                    0
# Region                     0
# GDP_Per_Capita           100
# Social_Support           100
# Life_Expectancy          100
# Freedom                  100
# Generosity                 0
# Corruption_Perception      0
# Unemployment_Rate         50
# Population                50
# Happiness_Score          100
# Happiness_Rank            50
# dtype: int64

# %%
df['GDP_Per_Capita'] = df['GDP_Per_Capita'].fillna(df['GDP_Per_Capita'].mean())
df['Social_Support'] = df['Social_Support'].fillna(df['Social_Support'].mean())
df['Life_Expectancy'] = df['Life_Expectancy'].fillna(df['Life_Expectancy'].mean())
df['Freedom'] = df['Freedom'].fillna(df['Freedom'].mean())
df['Happiness_Score'] = df['Happiness_Score'].fillna(df['Happiness_Score'].mean())
df['Happiness_Rank'] = df['Happiness_Rank'].fillna(df['Happiness_Rank'].mode())

df.head()
# Out:
#    Country         Region  GDP_Per_Capita  Social_Support  Life_Expectancy  \
# 0  Germany         Europe           1.963           0.951             79.9
# 1   Brazil        Oceania           2.467           0.396             80.2
# 2  Denmark        Oceania           2.407           0.529             75.3
# 3   France  South America           2.500           0.691             81.8
# 4      UAE        Oceania           2.152           0.795             81.4
#
#    Freedom  Generosity  Corruption_Perception  Unemployment_Rate  \
# 0    0.696       0.379                  0.421               14.5
# 1    0.609       0.465                  0.869               10.9
# 2    0.555       0.723                  0.038               16.2
# 3    0.351       0.160                  0.336                7.5
# 4    0.545       0.092                  0.832                3.0
#
#      Population  Happiness_Score  Happiness_Rank
# 0  1.372746e+09              8.0             1.0
# 1  2.846487e+08              8.0             2.0
# 2  1.286865e+09              8.0             3.0
# 3  4.601629e+08              8.0             4.0
# 4  1.374036e+09              8.0             5.0

# %%
df.rename(columns={"Region": "State"}, inplace=True)
df.head()
# Out:
#    Country          State  GDP_Per_Capita  Social_Support  Life_Expectancy  \
# 0  Germany         Europe           1.963           0.951             79.9
# 1   Brazil        Oceania           2.467           0.396             80.2
# 2  Denmark        Oceania           2.407           0.529             75.3
# 3   France  South America           2.500           0.691             81.8
# 4      UAE        Oceania           2.152           0.795             81.4
#
#    Freedom  Generosity  Corruption_Perception  Unemployment_Rate  \
# 0    0.696       0.379                  0.421               14.5
# 1    0.609       0.465                  0.869               10.9
# 2    0.555       0.723                  0.038               16.2
# 3    0.351       0.160                  0.336                7.5
# 4    0.545       0.092                  0.832                3.0
#
#      Population  Happiness_Score  Happiness_Rank
# 0  1.372746e+09              8.0             1.0
# 1  2.846487e+08              8.0             2.0
# 2  1.286865e+09              8.0             3.0
# 3  4.601629e+08              8.0             4.0
# 4  1.374036e+09              8.0             5.0

# %% [markdown]
# * Top 15 countries with happiness score

# %%
top_happiness = df.groupby("Country")["Happiness_Score"].mean().head(15)

plt.figure(figsize=(12,5))
plt.plot(top_happiness,color="brown", marker="o")

plt.title("Top 15 Countries by Happiness Score")
plt.xlabel("Country")
plt.ylabel("Happiness Score")
plt.show()

# %% [markdown]
# * Top 5 states with happines score

# %%
top_happiness = df.groupby("State")["Happiness_Score"].mean().head(5)

plt.figure(figsize=(12,5))
plt.plot(top_happiness,color="cyan", marker="*")

plt.title("Top 5 States by Happiness Score")
plt.xlabel("States")
plt.ylabel("Happiness Score")
plt.show()

# %% [markdown]
# * Top 20 countries with GDP

# %%
top20 = df.groupby("Country")["GDP_Per_Capita"].sum().sort_values(ascending=False).head(20)

top20.plot(kind="bar",figsize=(12,5),color="purple")
plt.title("Top 20 Countries by GDP")
plt.xlabel("Country")
plt.ylabel("GDP")
plt.tight_layout()

plt.show()

# %% [markdown]
# * Healthy Life Expectancy

# %%
health = df.groupby("State")["Life_Expectancy"].mean()

health.plot(kind="bar",color="orange")
plt.title("Healthy Life Expectancy by State")
plt.xlabel("State")
plt.ylabel("Life Expectancy")
plt.tight_layout()

plt.show()

# %% [markdown]
# * Social Support

# %%
support = df.groupby("State")["Social_Support"].mean()

plt.figure(figsize=(8,8))
plt.pie(support, labels=support.index, autopct="%1.1f%%", startangle=90)
plt.title("Average Social Support by State")

plt.show()

# %% [markdown]
# * Healthy Life Expectancy Impact on Happiness Score

# %%
plt.figure(figsize=(10,5))

plt.scatter(df["Life_Expectancy"].head(50), df["Happiness_Score"].head(50),c=np.random.rand(50),cmap="rainbow",s=100)
plt.title("Healthy Life Expectancy vs Happiness Score")
plt.xlabel("Healthy Life Expectancy")
plt.ylabel("Happiness Score")

plt.show()

# %% [markdown]
# * Correlation Heatmap

# %%
plt.figure(figsize=(10,6))

sns.heatmap(df.corr(numeric_only=True),  annot=True,  cmap="YlGnBu", linewidths=0.5)
plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# * Happiness Rate (%)

# %%
df["Happiness Rate"] = (df["Happiness_Score"] / df["Happiness_Score"].max()) * 100

df.head()

# %% [markdown]
# * Average Happiness Rate

# %%
print("Average Happiness Rate:", df["Happiness Rate"].mean())
# Out:
# Average Happiness Rate: 80.07739795918367

# %%
def category(score):
    if score >= 7:
        return "Excellent"
    elif score >= 6:
        return "Good"
    elif score >= 5:
        return "Average"
    else:
        return "Poor"

df["Happiness Category"] = df["Happiness_Score"].apply(category)

df.head()
# Out:
#    Country          State  GDP_Per_Capita  Social_Support  Life_Expectancy  \
# 0  Germany         Europe           1.963           0.951             79.9
# 1   Brazil        Oceania           2.467           0.396             80.2
# 2  Denmark        Oceania           2.407           0.529             75.3
# 3   France  South America           2.500           0.691             81.8
# 4      UAE        Oceania           2.152           0.795             81.4
#
#    Freedom  Generosity  Corruption_Perception  Unemployment_Rate  \
# 0    0.696       0.379                  0.421               14.5
# 1    0.609       0.465                  0.869               10.9
# 2    0.555       0.723                  0.038               16.2
# 3    0.351       0.160                  0.336                7.5
# 4    0.545       0.092                  0.832                3.0
#
#      Population  Happiness_Score  Happiness_Rank  Happiness Rate  \
# 0  1.372746e+09              8.0             1.0           100.0
# 1  2.846487e+08              8.0             2.0           100.0
# 2  1.286865e+09              8.0             3.0           100.0
# 3  4.601629e+08              8.0             4.0           100.0
# 4  1.374036e+09              8.0             5.0           100.0
#
#   Happiness Category
# 0          Excellent
# 1          Excellent
# 2          Excellent
# 3          Excellent
# 4          Excellent
