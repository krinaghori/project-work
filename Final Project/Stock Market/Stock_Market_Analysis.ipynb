# %% [markdown]
# --------------- Stock_Market_Analysis ---------------

# %% [markdown]
# * Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * Load Dataset

# %%
df = pd.read_csv('Stock_Market_Analysis.csv')
df.head()
# Out:
#    Trade_ID        Date      Company     Open     High      Low    Close  \
# 0         1  2024-01-01          SBI  1322.33  1333.17  1248.79  1281.40
# 1         2  2024-01-02     Reliance  1205.60  1318.19  1112.19  1265.12
# 2         3  2024-01-03          TCS  1417.74  1557.69  1268.55  1541.47
# 3         4  2024-01-04  Tata Motors  1965.67  2068.55  1945.58  2031.69
# 4         5  2024-01-05      Infosys   442.83   542.41   400.97   451.06
#
#      Volume  Market_Cap_Cr  PE_Ratio
# 0   74484.0        84018.0       5.0
# 1  778932.0       376463.0      21.0
# 2  923065.0        98200.0      55.0
# 3  937572.0       122553.0      10.0
# 4  148741.0       498995.0      27.0

# %% [markdown]
#  * Dataset Information

# %%
df.head()
# Out:
#    Trade_ID        Date      Company     Open     High      Low    Close  \
# 0         1  2024-01-01          SBI  1322.33  1333.17  1248.79  1281.40
# 1         2  2024-01-02     Reliance  1205.60  1318.19  1112.19  1265.12
# 2         3  2024-01-03          TCS  1417.74  1557.69  1268.55  1541.47
# 3         4  2024-01-04  Tata Motors  1965.67  2068.55  1945.58  2031.69
# 4         5  2024-01-05      Infosys   442.83   542.41   400.97   451.06
#
#      Volume  Market_Cap_Cr  PE_Ratio
# 0   74484.0        84018.0       5.0
# 1  778932.0       376463.0      21.0
# 2  923065.0        98200.0      55.0
# 3  937572.0       122553.0      10.0
# 4  148741.0       498995.0      27.0

# %%
df.tail()
# Out:
#       Trade_ID        Date      Company     Open     High      Low    Close  \
# 4995      4996  2024-09-07      Infosys  2834.39  2855.85  2714.41  2758.65
# 4996      4997  2024-09-08          SBI  1326.89  1466.53  1179.80  1454.48
# 4997      4998  2024-09-09  Tata Motors   994.68  1092.39   848.62   883.81
# 4998      4999  2024-09-10          SBI  1043.86  1185.89   902.85  1164.08
# 4999      5000  2024-09-11        Adani  2179.70  2292.79  2129.18  2231.87
#
#         Volume  Market_Cap_Cr  PE_Ratio
# 4995   58871.0       211442.0      41.0
# 4996  832631.0       268612.0      45.0
# 4997   88956.0       311600.0      45.0
# 4998  673294.0       329472.0      24.0
# 4999  695269.0        53311.0      10.0

# %%
print(df.dtypes)
print()
# Out:
# Trade_ID           int64
# Date                 str
# Company              str
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# Market_Cap_Cr    float64
# PE_Ratio         float64
# dtype: object

# %%
print("Shape :", df.shape)
print()
# Out:
# Shape : (5000, 10)

# %%
print("Columns:", df.columns)
print()
# Out:
# Columns: Index(['Trade_ID', 'Date', 'Company', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'Market_Cap_Cr', 'PE_Ratio'],
#       dtype='str')

# %%
print("Information: ")
print(df.info())
print()
# Out:
# Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Trade_ID       5000 non-null   int64
#  1   Date           5000 non-null   str
#  2   Company        5000 non-null   str
#  3   Open           5000 non-null   float64
#  4   High           5000 non-null   float64
#  5   Low            5000 non-null   float64
#  6   Close          5000 non-null   float64
#  7   Volume         4900 non-null   float64
#  8   Market_Cap_Cr  4900 non-null   float64
#  9   PE_Ratio       4900 non-null   float64
# dtypes: float64(7), int64(1), str(2)
# memory usage: 390.8 KB
# None

# %%
print("Statistical Summary:")
display(df.describe())
# Out:
# Statistical Summary:
#           Trade_ID         Open         High          Low        Close  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   2500.500000  1557.209794  1632.853176  1483.233618  1557.635120
# std    1443.520003   840.346090   841.394765   840.886369   842.026227
# min       1.000000   100.700000   113.670000    50.000000    50.460000
# 25%    1250.750000   823.772500   902.275000   748.887500   817.137500
# 50%    2500.500000  1562.075000  1638.045000  1488.570000  1563.405000
# 75%    3750.250000  2283.820000  2358.902500  2208.152500  2285.340000
# max    5000.000000  2999.830000  3142.200000  2994.860000  3112.500000
#
#               Volume  Market_Cap_Cr     PE_Ratio
# count    4900.000000    4900.000000  4900.000000
# mean   509424.066327  255442.988776    32.815714
# std    286938.174800  143246.178301    16.270640
# min      1794.000000    5154.000000     5.000000
# 25%    262623.250000  128938.750000    19.000000
# 50%    518546.500000  256864.000000    33.000000
# 75%    755562.750000  378932.250000    47.000000
# max    999784.000000  499840.000000    60.000000

# %% [markdown]
# * Dataframe Operations

# %%
df["Volume"]
# Out:
# 0        74484.0
# 1       778932.0
# 2       923065.0
# 3       937572.0
# 4       148741.0
#           ...
# 4995     58871.0
# 4996    832631.0
# 4997     88956.0
# 4998    673294.0
# 4999    695269.0
# Name: Volume, Length: 5000, dtype: float64

# %%
df[df["Volume"] > 50000]
# Out:
#       Trade_ID        Date      Company     Open     High      Low    Close  \
# 0            1  2024-01-01          SBI  1322.33  1333.17  1248.79  1281.40
# 1            2  2024-01-02     Reliance  1205.60  1318.19  1112.19  1265.12
# 2            3  2024-01-03          TCS  1417.74  1557.69  1268.55  1541.47
# 3            4  2024-01-04  Tata Motors  1965.67  2068.55  1945.58  2031.69
# 4            5  2024-01-05      Infosys   442.83   542.41   400.97   451.06
# ...        ...         ...          ...      ...      ...      ...      ...
# 4995      4996  2024-09-07      Infosys  2834.39  2855.85  2714.41  2758.65
# 4996      4997  2024-09-08          SBI  1326.89  1466.53  1179.80  1454.48
# 4997      4998  2024-09-09  Tata Motors   994.68  1092.39   848.62   883.81
# 4998      4999  2024-09-10          SBI  1043.86  1185.89   902.85  1164.08
# 4999      5000  2024-09-11        Adani  2179.70  2292.79  2129.18  2231.87
#
#         Volume  Market_Cap_Cr  PE_Ratio
# 0      74484.0        84018.0       5.0
# 1     778932.0       376463.0      21.0
# 2     923065.0        98200.0      55.0
# 3     937572.0       122553.0      10.0
# 4     148741.0       498995.0      27.0
# ...        ...            ...       ...
# 4995   58871.0       211442.0      41.0
# 4996  832631.0       268612.0      45.0
# 4997   88956.0       311600.0      45.0
# 4998  673294.0       329472.0      24.0
# 4999  695269.0        53311.0      10.0
#
# [4678 rows x 10 columns]

# %%
df.sort_values(by="High", ascending=False)
# Out:
#       Trade_ID        Date      Company     Open     High      Low    Close  \
# 951        952  2024-08-09        ICICI  2999.18  3142.20  2929.35  3094.04
# 2169      2170  2024-12-10  Tata Motors  2999.59  3140.89  2920.99  3013.53
# 4184      4185  2024-06-18     Reliance  2998.72  3134.54  2994.86  3077.03
# 878        879  2024-05-28  Tata Motors  2993.38  3126.69  2931.97  3090.53
# 561        562  2024-07-15        Adani  2991.01  3126.65  2900.16  2929.89
# ...        ...         ...          ...      ...      ...      ...      ...
# 837        838  2024-04-17        ICICI   123.77   136.20    68.08    91.63
# 3772      3773  2024-05-02      Infosys   105.95   135.49    50.00   118.75
# 4549      4550  2024-06-18        Wipro   114.60   120.73    50.00    95.23
# 4595      4596  2024-08-03        Adani   106.20   115.03    50.00    58.85
# 3331      3332  2024-02-16     Reliance   109.22   113.67    50.00    84.17
#
#         Volume  Market_Cap_Cr  PE_Ratio
# 951   869938.0       319260.0      58.0
# 2169  847585.0       210225.0      17.0
# 4184  339505.0       365711.0       NaN
# 878   331977.0       171673.0      36.0
# 561   468273.0       169506.0      24.0
# ...        ...            ...       ...
# 837   181765.0       330408.0      53.0
# 3772  287322.0       274513.0      51.0
# 4549  612672.0        10207.0      49.0
# 4595  965148.0        88964.0      39.0
# 3331  149903.0       435436.0      38.0
#
# [5000 rows x 10 columns]

# %%
df["Close"].value_counts()
# Out:
# Close
# 1427.90    2
# 474.11     2
# 1100.30    2
# 332.83     2
# 2118.32    2
#           ..
# 2758.65    1
# 1454.48    1
# 883.81     1
# 1164.08    1
# 2231.87    1
# Name: count, Length: 4954, dtype: int64

# %%
print("Maximum High: " ,df["High"].max())
print("Maximum Low:",df["Low"].max())
print("Maximum Close: ",df["Close"].max())
print("Maximum Volume: ",df["Volume"].max())
print("Maximum Market_Cap_Cr: ",df["Market_Cap_Cr"].max())
print("Maximum PE_Ratio: ",df["PE_Ratio"].max())
# Out:
# Maximum High:  3142.2
# Maximum Low: 2994.86
# Maximum Close:  3112.5
# Maximum Volume:  999784.0
# Maximum Market_Cap_Cr:  499840.0
# Maximum PE_Ratio:  60.0

# %% [markdown]
# * Check Missing Values

# %%
print(df.isnull().sum())
# Out:
# Trade_ID           0
# Date               0
# Company            0
# Open               0
# High               0
# Low                0
# Close              0
# Volume           100
# Market_Cap_Cr    100
# PE_Ratio         100
# dtype: int64

# %% [markdown]
# * Fill Missing Values

# %%
df['Volume'] = df['Volume'].fillna(df['Volume'].mean())
df['Market_Cap_Cr'] = df['Market_Cap_Cr'].fillna(df['Market_Cap_Cr'].mean())
df['PE_Ratio'] = df['PE_Ratio'].fillna(df['PE_Ratio'].mean())

df.head()
# Out:
#    Trade_ID        Date      Company     Open     High      Low    Close  \
# 0         1  2024-01-01          SBI  1322.33  1333.17  1248.79  1281.40
# 1         2  2024-01-02     Reliance  1205.60  1318.19  1112.19  1265.12
# 2         3  2024-01-03          TCS  1417.74  1557.69  1268.55  1541.47
# 3         4  2024-01-04  Tata Motors  1965.67  2068.55  1945.58  2031.69
# 4         5  2024-01-05      Infosys   442.83   542.41   400.97   451.06
#
#      Volume  Market_Cap_Cr  PE_Ratio
# 0   74484.0        84018.0       5.0
# 1  778932.0       376463.0      21.0
# 2  923065.0        98200.0      55.0
# 3  937572.0       122553.0      10.0
# 4  148741.0       498995.0      27.0

# %% [markdown]
# * Convert Date Column

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%d/%m/%Y')
df.head()
# Out:
#    Trade_ID        Date      Company     Open     High      Low    Close  \
# 0         1  01/01/2024          SBI  1322.33  1333.17  1248.79  1281.40
# 1         2  02/01/2024     Reliance  1205.60  1318.19  1112.19  1265.12
# 2         3  03/01/2024          TCS  1417.74  1557.69  1268.55  1541.47
# 3         4  04/01/2024  Tata Motors  1965.67  2068.55  1945.58  2031.69
# 4         5  05/01/2024      Infosys   442.83   542.41   400.97   451.06
#
#      Volume  Market_Cap_Cr  PE_Ratio
# 0   74484.0        84018.0       5.0
# 1  778932.0       376463.0      21.0
# 2  923065.0        98200.0      55.0
# 3  937572.0       122553.0      10.0
# 4  148741.0       498995.0      27.0

# %% [markdown]
# * Average Closing Price by Company

# %%
close_price = df.groupby("Company")["Close"].mean()

plt.figure(figsize=(10,5))
plt.plot(close_price.index, close_price.values,  marker='o', linewidth=2, color='blue')
plt.title("Average Closing Price by Company")
plt.xlabel("Company")
plt.ylabel("Average Close Price")

plt.show()

# %% [markdown]
# * Average Trading Volume by Company

# %%
volume = df.groupby("Company")["Volume"].mean()

plt.figure(figsize=(10,5))
plt.bar(volume.index, volume.values, color="green")
plt.title("Average Trading Volume by Company")
plt.xlabel("Company")
plt.ylabel("Average Volume")

plt.show()

# %% [markdown]
# * Company Record Distribution

# %%
company = df["Company"].value_counts()

plt.figure(figsize=(8,8))
plt.pie(company, labels=company.index, autopct="%1.1f%%", startangle=90)
plt.title("Company Wise Record Distribution")

plt.show()

# %% [markdown]
# * Closing Price Distribution

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Close"], bins=20, color="orange", edgecolor="black")
plt.title("Distribution of Closing Price")
plt.xlabel("Closing Price")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# * Open Price vs Close Price

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["Open"].head(500), df["Close"].head(500), color="red")
plt.title("Open Price vs Close Price")
plt.xlabel("Open Price")
plt.ylabel("Close Price")

plt.show()

# %% [markdown]
# * Correlation Matrix

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", linewidths=0.1)
plt.title("Stock Market Correlation Heatmap")

plt.show()
